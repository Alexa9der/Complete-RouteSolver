# %%
from lib.project_functions import *

# %%
cdag = Clear_Data_After_Geocoding()
m, m_e, data, data_e = cdag.get_result()

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
m_e
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
data
# Out:
#                                                address  longitude   latitude  \
# 0             Poland, 05-822, Milanówek, Królewska, 27  20.689051  52.125065
# 1        Poland, 05-090, Raszyn, Unii Europejskiej, 15  20.923553  52.153702
# 2             Poland, 96-321, Siestrzeń, Objazdowa, 26  20.709194  52.050420
# 3               Poland, 05-090, Wypędy, Sokołowska, 18  20.887331  52.143402
# 4    Poland, 05-825, Kozerki, Gen. Orlicz-Dreszera, 19  20.596220  52.095340
# ..                                                 ...        ...        ...
# 549        Poland, 05-825, Chrzanów Mały, Pączkowa, 30  20.626043  52.139803
# 550  Poland, 05-831, Wola Krakowiańska, Jastrzębska...  20.801157  52.028348
# 551            Poland, 02-777, Warszawa, Cynamonowa, 8  21.047780  52.151150
# 552            Poland, 02-445, Warszawa, Potrzebna, 33  20.919093  52.209877
# 553                    Turystyczna 38, 05-830 Nadarzyn  20.808857  52.105101
#
#      distance_to_depo
# ...

# %%
data_e
# Out:
#                                               address  longitude   latitude  \
# 0    Poland, 05-825, Chrzanów Mały, Chrzanów Mały, 29  19.467479  50.160239
# 1                   Poland, , Gołków, ul. Zielona, 31        NaN        NaN
# 2              Poland, 05-831, Rozalin, Kostowiec, 28        NaN        NaN
# 3   Poland, 05-825, Grodzisk Mazowiecki, M. Langie...        NaN        NaN
# 4              Poland, 00-847, Warszawa, Towarowa, 24        NaN        NaN
# 5   Poland, 02-495, Warszawa, Dyrekcyjna / Silniko...        NaN        NaN
# 6     Poland, 05-825, Grodzisk Mazowiecki, 1 Maja, 30        NaN        NaN
# 7             Poland, 05-800, Pruszków, 3-go maja, 24        NaN        NaN
# 8       Poland, 96-316 , Międzyborów, Międzyborów, 32        NaN        NaN
# 9   Poland, 05-825, Grodzisk Mazowiecki, 11-go Lis...        NaN        NaN
# 10                Poland, 05-870, Błonie, Os.Pass, 27        NaN        NaN
# ...

# %%
cdag.save()
# Out:
# Data saved to folder: data/data_after_geocoding
